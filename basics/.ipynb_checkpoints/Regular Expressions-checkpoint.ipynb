# %%
import nltk
import re

# %%
full_text = nltk.corpus.gutenberg.words("chesterton-ball.txt")

# %%
set([word for word in full_text if re.search("n$",word)])
# Out:
# {'Again',
#  'Ain',
#  'An',
#  'Arabian',
#  'Arcadian',
#  'Association',
#  'Assyrian',
#  'Balan',
#  'Balin',
#  'Ben',
#  'Benediction',
#  'Between',
#  'Brighton',
#  'Bunyan',
#  'Californian',
#  'Cameron',
#  'Can',
#  'Chesterton',
#  'Christian',
#  'Constitution',
#  'Convention',
#  'Croydon',
#  'Crucifixion',
#  'Culloden',
#  'Damn',
#  'Dawson',
#  'Doesn',
#  'Domain',
#  'Don',
#  'Down',
#  'Eden',
#  'Emerson',
#  'Englishman',
#  'Englishmen',
#  'Evan',
#  'Even',
#  'Fagin',
#  'Foundation',
#  'Garden',
#  'Gentlemen',
#  'German',
#  'Godwin',
#  'Golden',
#  'Gordon',
#  'Hampton',
#  'Hanoverian',
#  'Hauptmann',
#  'Haven',
#  'Heaven',
#  'Hutton',
#  'Identification',
#  'In',
#  'Information',
#  'Inn',
#  'Inquisition',
#  'Italian',
#  'Joan',
#  'John',
#  'Julian',
#  'Latin',
#  'Lion',
#  'Listen',
#  'London',
#  'MacIan',
#  'Magdalen',
#  'Man',
#  'Martin',
#  'Massillon',
#  'Men',
#  'Mesopotamian',
#  'Michigan',
#  'Mountain',
# ...

# %%
set([word for word in full_text if re.search("^.*br.*",word)])
# Out:
# {'Bolingbroke',
#  'Cambridge',
#  'February',
#  'Nebraska',
#  'Shoolbreds',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'abruptness',
#  'brac',
#  'bracken',
#  'braids',
#  'brain',
#  'brains',
#  'branch',
#  'branches',
#  'branching',
#  'brandishing',
#  'brandy',
#  'braver',
#  'bravery',
#  'brawl',
#  'brazenly',
#  'bread',
#  'breadth',
#  'break',
#  'breakfast',
#  'breaking',
#  'breakwater',
#  'breast',
#  'breath',
#  'breathe',
#  'breathing',
#  'breathless',
#  'breathlessly',
#  'bred',
#  'breeches',
#  'breeds',
#  'breeze',
#  'brevity',
#  'bribed',
#  'bric',
#  'brick',
#  'bridge',
#  'bridges',
#  'bridled',
#  'brief',
#  'briefest',
#  'briefly',
#  'brigand',
#  'bright',
#  'brighter',
#  'brightest',
#  'brightly',
#  'brilliancy',
#  'brilliant',
#  'brilliantly',
#  'brim',
#  'brimmed',
#  'bring',
#  'bringing',
#  'brink',
#  'brisk',
#  'brittle',
#  'broad',
#  'broadened',
#  'broadening',
#  'broader',
#  'broadest',
#  'broadminded',
# ...
